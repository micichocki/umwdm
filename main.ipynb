# %% [markdown]
# # ChestMnist Dataset

# %%
from medmnist import INFO, ChestMnist
import numpy as np
import matplotlib as plt

# get dataset info
print(INFO)

# get ChestMnist dataset class
dataset = ChestMnist(root='./data', split='train', download=True)
